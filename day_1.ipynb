# %% [markdown]
# <a href="https://colab.research.google.com/github/sriakhilsurapaneni/cv-clomotech-practice/blob/main/grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
image=cv.imread('botanical.png')

# %%
# !pwd
# !ls
# Out:
# /content
# botanical.png  img.jpg	sample_data

# %%
image=cv.cvtColor(image,cv.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(12, 7))
plt.imshow(image)

# %%
print(image.shape[:2])
# Out:
# (4096, 3072)

# %%
plt.imshow(cv.cvtColor(cv.cvtColor(image,cv.COLOR_BGR2GRAY),cv.COLOR_BGR2RGB))
